# %%
pip install msoffcrypto-tool
# Out:
# ...
#      |████████████████████████████████| 209 kB 2.1 MB/s eta 0:00:01
# ...
#   Created wheel for msoffcrypto-tool: filename=msoffcrypto_tool-4.10.1-py3-none-any.whl size=30480 sha256=093a047dacd844f0a0dcbc78472c66733555935e099ddeb001d7acd57a8375a9
#   Stored in directory: /root/.cache/pip/wheels/cd/ac/c4/e552b631884346dd615f2ac834a16b030db2c0d2d4308e0b3f
# Successfully built msoffcrypto-tool
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import tempfile
import msoffcrypto
from pathlib import Path

# %%
file_dir = Path(r"file:///Users/hi/ds_python/ROX/")
password = "roxsenko"
sheet_name1 = "サンプル客数"
sheet_name2 = "天気データ"

# %%
data_f1 = pd.read_csv("サンプル客数.csv")
data_f2 = pd.read_csv("天気データ.csv")

# %%
data_f1 = data_f1.drop([0])

# %%
data_f1
# Out:
#           Date time0_1 time1_2 time2_3 time3_4 time4_5 time5_6 time6_7  \
# 1    2017/12/1       0      24      42      52      58      84      62
# 2    2017/12/2       0      28      44      72     100     126      96
# 3    2017/12/3       0      14      46      64     100      92      98
# 4    2017/12/4       0      18      46      52      66      70      78
# 5    2017/12/5       0      16      56      64      64      80      58
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 787  2020/1/26       0      10      40      38      66     100      96
# 788  2020/1/27       0       8      22      54      64      88      42
# 789  2020/1/28       0      12      42      42      32      36      54
# 790  2020/1/29       0       8      28      28      60      56      46
# 791  2020/1/30       0      24      30      32      74      58      62
#
#     time7_8 time8_9 time9_10 time10_11 time11_12 time12_13 time13_14  \
# ...

# %%
data_f1
# Out:
#           Date time0_1 time1_2 time2_3 time3_4 time4_5 time5_6 time6_7  \
# 1    2017/12/1       0      24      42      52      58      84      62
# 2    2017/12/2       0      28      44      72     100     126      96
# 3    2017/12/3       0      14      46      64     100      92      98
# 4    2017/12/4       0      18      46      52      66      70      78
# 5    2017/12/5       0      16      56      64      64      80      58
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 787  2020/1/26       0      10      40      38      66     100      96
# 788  2020/1/27       0       8      22      54      64      88      42
# 789  2020/1/28       0      12      42      42      32      36      54
# 790  2020/1/29       0       8      28      28      60      56      46
# 791  2020/1/30       0      24      30      32      74      58      62
#
#     time7_8 time8_9 time9_10 time10_11 time11_12 time12_13 time13_14  \
# ...

# %%
# x = 0
# count = 0
# data_f1_new = data_f1

# for i in range(len(data_f1)):
#     for j in range(len(data_f1.loc[1])-1):
#         if x < int(data_f1.loc[i+1][j+1]):
#             x = int(data_f1.loc[i+1][j+1])
#     if x == 0:
#         data_f1_new = data_f1_new.drop([i])
# #     count += 1
# #     print(x,count)
#     x = 0

# data_f1_new
